# %%
import pandas as pd

# %%
data_file = "Resources/cities.csv"

# %%
data_df = pd.read_csv(data_file)

# %%
data_df
# Out:
#      Unnamed: 0       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             0       mayo  38.8876  -76.5119     30.99        86          90
# 1             1       nome  64.5011 -165.4064    -13.00        70           1
# 2             2    mataura -46.1927  168.8643     51.01        92          70
# 3             3   cherskiy  68.7500  161.3000    -29.40        97           0
# 4             4     castro -24.7911  -50.0119     78.28        42           0
# ..          ...        ...      ...       ...       ...       ...         ...
# 554         554     moscow  55.7522   37.6156      3.20        78           0
# 555         555   buraydah  26.3260   43.9750     59.00        47           0
# 556         556  sovetskiy  61.3614   63.5842    -25.06        94           0
# 557         557        leh  34.1667   77.5833      7.50        24           0
# 558         558    ladario -19.0047  -57.6017     91.40        51          20
#
# ...

# %%
data_df.to_html('table.html')

# %%
# !open table.html
